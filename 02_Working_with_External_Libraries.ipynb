# %% [markdown]
# # Working with External Libraries

# %% [markdown]
# Source - Kaggle - [Working with External Libraries](https://www.kaggle.com/code/colinmorris/working-with-external-libraries)
# 1. `type()`(what is this thing?) - [type()](https://docs.python.org/3/library/functions.html?highlight=dir#type)
# 2. `dir()`(What can I do with it?) - [dir()](https://docs.python.org/3/library/functions.html?highlight=dir#dir)
# 3. `help()`- (Tell me more) - [help()](https://docs.python.org/3/library/functions.html?highlight=dir#help)
# 4. `inspect()` - [inspect()](https://docs.python.org/3/library/inspect.html) - The inspect module provides several useful functions to help get information about live objects such as modules, classes, methods, functions, tracebacks, frame objects, and code objects.

# %% [markdown]
# ## Built-in Python Functions
# - [Built-in Functions](https://docs.python.org/3/library/functions.html?highlight=dir#getattr)

# %% [markdown]
# ## The Meaning of Underscores in Python
# - [Link](https://dbader.org/blog/meaning-of-underscores-in-python)

# %% [markdown]
# ## Examples

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
type(np)
# Out:
# module

# %%
print(dir(matplotlib))
# Out:
# ['ExecutableNotFoundError', 'LooseVersion', 'MatplotlibDeprecationWarning', 'MutableMapping', 'Parameter', 'Path', 'RcParams', 'URL_REGEX', '_DATA_DOC_APPENDIX', '_DATA_DOC_TITLE', '_ExecInfo', '__bibtex__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_add_data_doc', '_all_deprecated', '_animation_data', '_check_versions', '_cm', '_cm_listed', '_color_data', '_constrained_layout', '_deprecated_ignore_map', '_deprecated_map', '_deprecated_remain_as_none', '_ensure_handler', '_get_config_or_cache_dir', '_get_data_path', '_get_executable_info', '_get_ssl_context', '_get_xdg_cache_dir', '_get_xdg_config_dir', '_image', '_init_tests', '_label_from_arg', '_layoutbox', '_log', '_logged_cached', '_mathtext_data', '_open_file_or_url', '_path', '_preprocess_data', '_pylab_helpers', '_rc_params_in_file', '_replacer', '_text_layout', '_version', 'afm', 'animation', 'artist', 'atexit', 'axes', 'axis', 'backe
# ...

# %%
help(matplotlib.rcParams)
# Out:
# Help on RcParams in module matplotlib object:
#
# class RcParams(collections.abc.MutableMapping, builtins.dict)
#  |  RcParams(*args, **kwargs)
#  |
#  |  A dictionary object including validation.
#  |
#  |  Validating functions are defined and associated with rc parameters in
#  |  :mod:`matplotlib.rcsetup`.
#  |
#  |  See Also
#  |  --------
#  |  :ref:`customizing-with-matplotlibrc-files`
#  |
#  |  Method resolution order:
#  |      RcParams
#  |      collections.abc.MutableMapping
#  |      collections.abc.Mapping
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, key)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Yield sorted list of keys.
# ...

# %%
import inspect
inspect.getmembers(matplotlib)
# Out:
# [('ExecutableNotFoundError', matplotlib.ExecutableNotFoundError),
#  ('LooseVersion', distutils.version.LooseVersion),
#  ('MatplotlibDeprecationWarning',
#   matplotlib.cbook.deprecation.MatplotlibDeprecationWarning),
#  ('MutableMapping', collections.abc.MutableMapping),
#  ('Parameter', inspect.Parameter),
#  ('Path', pathlib.Path),
#  ('RcParams', matplotlib.RcParams),
#  ('URL_REGEX', re.compile(r'^http://|^https://|^ftp://|^file:', re.UNICODE)),
#  ('_DATA_DOC_APPENDIX',
#   '\n\n.. note::\n    In addition to the above described arguments, this function can take\n    a *data* keyword argument. If such a *data* argument is given,\n{replaced}\n\n    Objects passed as **data** must support item access (``data[s]``) and\n    membership test (``s in data``).\n'),
#  ('_DATA_DOC_TITLE', '\n\nNotes\n-----\n'),
#  ('_ExecInfo', matplotlib._ExecInfo),
#  ('__bibtex__',
# ...
